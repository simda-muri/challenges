# %% [markdown]
# # Challenge Problem 2: Lagrangian Observation Mapping
#
# For the Lagrangian observation mapping, please check the following Git repository
#
# Multi-marginal Optimal Transport (MMOT)
# https://github.com/simda-muri/mmot
#
# and tutorials therein.
